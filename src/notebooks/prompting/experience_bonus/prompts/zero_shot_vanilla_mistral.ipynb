# %%
import os
os.sys.path.append(os.path.join(os.getcwd(), "../../../.."))
from models.Prompt import PromptRunParameters
from prompting.run_prompt import WrapperEnum, run_prompts
from prompting.get_prompts import zero_shot_vanilla
from prompting.get_themes_list import selected_level_1_themes_first_version

# %%
"""
! ONLY EDIT THIS CELL
"""

#? Defines the themes list and its associated hierarchy level (0 to 3)
THEMES_LIST, THEMES_HIERARCHY_LEVEL = selected_level_1_themes_first_version()
#? Defines the list of prompts to use, its associated prompt type (zero-shot, one-shot, etc.)
PROMPTS, ASSOC, ACCEPTED_THEMES_FOR_QUESTION, PROMPT_TYPES = zero_shot_vanilla(THEMES_LIST, THEMES_HIERARCHY_LEVEL)

#? Specify the API wrapper to use for calling the LLM
WRAPPER = WrapperEnum.Mistral
#? Define the model to use with the wrapper (available models can be found in the PROMPTING.md file)
MODEL = "open-mistral-nemo-2407"
#? Set the temperature parameter for the model to control randomness (0.0 = deterministic, 1.0 = random)
TEMPERATURE = 0.0

#? The identifier for the batch of questions being processed. Set to None if no Batch should be used
BATCH_ID = "66f9ca5824e5760146e2783a"
#? Number of questions sampled from the database. Will create a Batch based on the themes list
QUESTION_SAMPLE_SIZE = 1500

# ? Name for the run
NAME = f"zero shot {MODEL}"
#? Add a comment to be able to identify each run
DESCRIPTION = f"experience #bonus zero shot vanilla {MODEL}"
#? If the API calls starts to be slower, increase the sleep time
SLEEP_TIME=5
#? Number of run to create with the same parameters
NUMBER_OF_RUNS=1
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Ta réponse doit contenir une seule chose: le thème correspondant, par exemple `retraites` ou `ministères et secrétariats d'état`. Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides.
#
# user: {0}

# %%
"""
! DO NOT EDIT THIS CELL
"""
PARAMETERS = PromptRunParameters(
    temperature=TEMPERATURE,
    model=MODEL,
    types=PROMPT_TYPES,
    theme_hierarchy_level=THEMES_HIERARCHY_LEVEL,
    wrapper=WRAPPER
)

# %%
"""
! DO NOT EDIT THIS CELL
"""
for i in range(1, NUMBER_OF_RUNS + 1):
	run_prompts(
		parameters=PARAMETERS,
		prompts=PROMPTS,
		themes_list=THEMES_LIST,
		number_of_questions=QUESTION_SAMPLE_SIZE,
		batch_id=BATCH_ID,
		accepted_themes_for_questions=ACCEPTED_THEMES_FOR_QUESTION,
		description=DESCRIPTION,
		name=NAME,
		sleep_time=SLEEP_TIME
	)
# Out:
#   0%|          | 6/1500 [03:46<15:39:58, 37.75s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       1 """
#       2 ! DO NOT EDIT THIS CELL
#       3 """
#       4 for i in range(1, NUMBER_OF_RUNS + 1):
# ----> 5 	run_prompts(
#       6 		parameters=PARAMETERS,
#       7 		prompts=PROMPTS,
#       8 		themes_list=THEMES_LIST,
#       9 		number_of_questions=QUESTION_SAMPLE_SIZE,
#      10 		batch_id=BATCH_ID,
#      11 		accepted_themes_for_questions=ACCEPTED_THEMES_FOR_QUESTION,
#      12 		description=DESCRIPTION,
#      13 		name=NAME,
#      14 		sleep_time=SLEEP_TIME
#      15 	)
#
# File ~/Epitech/msc/parl-ia-ment/article/src/notebooks/prompting/experience_bonus/prompts/../../../../prompting/run_prompt.py:339, in run_prompts(parameters, prompts, themes_list, description, name, accepted_themes_for_questions, batch_id, number_of_questions, retrieve_theme_func, response_format, sleep_time, validation_func, dry_run)
#     337     for question in tqdm(question_list):
#     338         time.sleep(sleep_time)
# --> 339         run_prompt(
#     340             question=question,
#     341             prompt=prompt,
#     342             prompt_run=prompt_run,
#     343             prompt_run_id=str(inserted_prompt_run.inserted_id),
#     344             response_format=response_format,
#     345             retrieve_theme_func=retrieve_theme_func,
#     346             validation_func=validation_func,
#     347             dry_run=dry_run,
#     348         )
#     350     return PromptRunInfo(
#     351         run_id=str(inserted_prompt_run.inserted_id),
#     352         prompts=prompts,
#     353         prompt_run=prompt_run,
#     354     )
#     355 else:
#
# File ~/Epitech/msc/parl-ia-ment/article/src/notebooks/prompting/experience_bonus/prompts/../../../../prompting/run_prompt.py:136, in run_prompt(question, prompt, prompt_run_id, prompt_run, assoc, response_format, retrieve_theme_func, validation_func, dry_run)
#     128     response = prompt_anthropic(
#     129         prompt,
#     130         prompt_run,
#    (...)
#     133         retrieve_theme_func,
#     134     )
#     135 case WrapperEnum.Mistral:
# --> 136     response = prompt_mistral(
#     137         prompt,
#     138         prompt_run,
#     139         question_text,
#     140         assoc,
#     141         retrieve_theme_func,
#     142     )
#     143 case WrapperEnum.Google:
#     144     response = prompt_google(
#     145         prompt,
#     146         prompt_run,
#    (...)
#     149         retrieve_theme_func,
#     150     )
#
# File ~/Epitech/msc/parl-ia-ment/article/src/notebooks/prompting/experience_bonus/prompts/../../../../prompting/llm_wrappers.py:237, in prompt_mistral(prompt, prompt_run, question_text, assoc, retrieve_theme_func)
#     234         for k, v in assoc.items():
#     235             messages[i]["content"] = msg["content"].replace(k, v)
# --> 237 response = mistral_client.chat.complete(
#     238     model=prompt_run.parameters.model,
#     239     temperature=prompt_run.parameters.temperature,
#     240     max_tokens=MAX_TOKEN,
#     241     messages=messages,
#     242 )
#     244 if retrieve_theme_func is not None:
#     245     predicted_label = retrieve_theme_func(
#     246         prompt_run.themes_list,
#     247         prompt_run.parameters.theme_hierarchy_level,
#     248         response.choices[0].message.content,
#     249     )
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/mistralai/chat.py:116, in Chat.complete(self, model, messages, temperature, top_p, max_tokens, min_tokens, stream, stop, random_seed, response_format, tools, tool_choice, safe_prompt, retries, server_url, timeout_ms)
#     113 if isinstance(retries, utils.RetryConfig):
#     114     retry_config = (retries, ["429", "500", "502", "503", "504"])
# --> 116 http_res = self.do_request(
#     117     hook_ctx=HookContext(
#     118         operation_id="chat_completion_v1_chat_completions_post",
#     119         oauth2_scopes=[],
#     120         security_source=get_security_from_env(
#     121             self.sdk_configuration.security, models.Security
#     122         ),
#     123     ),
#     124     request=req,
#     125     error_status_codes=["422", "4XX", "5XX"],
#     126     retry_config=retry_config,
#     127 )
#     129 data: Any = None
#     130 if utils.match_response(http_res, "200", "application/json"):
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/mistralai/basesdk.py:257, in BaseSDK.do_request(self, hook_ctx, request, error_status_codes, stream, retry_config)
#     255     http_res = utils.retry(do, utils.Retries(retry_config[0], retry_config[1]))
#     256 else:
# --> 257     http_res = do()
#     259 if not utils.match_status_codes(error_status_codes, http_res.status_code):
#     260     http_res = self.sdk_configuration.get_hooks().after_success(
#     261         AfterSuccessContext(hook_ctx), http_res
#     262     )
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/mistralai/basesdk.py:218, in BaseSDK.do_request.<locals>.do()
#     208     req = self.sdk_configuration.get_hooks().before_request(
#     209         BeforeRequestContext(hook_ctx), request
#     210     )
#     211     logger.debug(
#     212         "Request:\nMethod: %s\nURL: %s\nHeaders: %s\nBody: %s",
#     213         req.method,
#    (...)
#     216         get_body_content(req),
#     217     )
# --> 218     http_res = client.send(req, stream=stream)
#     219 except Exception as e:
#     220     _, e = self.sdk_configuration.get_hooks().after_error(
#     221         AfterErrorContext(hook_ctx), None, e
#     222     )
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      97 except BaseException as exc:
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      74 with self._request_lock:
#      75     if self._connection is None:
# ---> 76         stream = self._connect(request)
#      78         ssl_object = stream.get_extra_info("ssl_object")
#      79         http2_negotiated = (
#      80             ssl_object is not None
#      81             and ssl_object.selected_alpn_protocol() == "h2"
#      82         )
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:122, in HTTPConnection._connect(self, request)
#     114     kwargs = {
#     115         "host": self._origin.host.decode("ascii"),
#     116         "port": self._origin.port,
#    (...)
#     119         "socket_options": self._socket_options,
#     120     }
#     121     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122         stream = self._network_backend.connect_tcp(**kwargs)
#     123         trace.return_value = stream
#     124 else:
#
# File ~/Epitech/msc/parl-ia-ment/article/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#     212         sock.setsockopt(*option)  # pragma: no cover
#
# File /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     835 if source_address:
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#     839 exceptions.clear()
#
# KeyboardInterrupt:
