# %%
import os

os.sys.path.append(os.path.join(os.getcwd(), "../../.."))
from charts.cohen import plot_cohen_kappa
from models.LLMOutput import ConfidenceType
from utils.helpers import print_prompts
from metrics.run import gather_data_for_run_ids
from charts.calibration import plot_confidence_calibration_curve
from metrics.agreement.krippendorff import compute_krippendorff_alpha
from charts.performance import (
    plot_precision,
    plot_recall,
    plot_f1_score,
    plot_support_counts,
    plot_precision_heatmap,
    plot_recall_heatmap,
    plot_f1_score_heatmap,
)

# %% [markdown]
# # Analyzing results for experience #2

# %%
RUN_IDS = [
    "66fabc8d4a0c432ccccb5d0a",
    "66fac0c64a0c432ccccb62e2",
    "66fac4df4a0c432ccccb68ba",
    "66fac9104a0c432ccccb6e92",
    "66fba917d61bb13c5214f949",
    "670669abd1631d98976ad5e1",
    "670678b3d1631d98976adb3e",
    "67068cf8a8496b140cb07dcb",
    "6706a081a8496b140cb08327",
    "6706b391a8496b140cb08884",
]

RUN_INFOS = gather_data_for_run_ids(RUN_IDS)

# %%
plot_support_counts(RUN_IDS, save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[0]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Ta réponse doit contenir une seule chose: le thème correspondant, par exemple `retraites` ou `ministères et secrétariats d'état`. Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides.
#
# user: {0}

# %%
plot_precision(RUN_IDS[0], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[0], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[0], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[1]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Ta réponse doit contenir une seule chose: le thème correspondant, par exemple `retraites` ou `ministères et secrétariats d'état`. Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides.
#
# user: {0}

# %%
plot_precision(RUN_IDS[1], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[1], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[1], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[2]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Ta réponse doit contenir une seule chose: le thème correspondant, par exemple `retraites` ou `ministères et secrétariats d'état`. Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides.
#
# user: {0}

# %%
plot_precision(RUN_IDS[2], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[2], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[2], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[3]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Ta réponse doit contenir une seule chose: le thème correspondant, par exemple `retraites` ou `ministères et secrétariats d'état`. Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides.
#
# user: {0}

# %%
plot_precision(RUN_IDS[3], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[3], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[3], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[4]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Ta réponse doit contenir une seule chose: le thème correspondant, par exemple `retraites` ou `ministères et secrétariats d'état`. Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides.
#
# user: {0}

# %%
plot_precision(RUN_IDS[4], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[4], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[4], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[5]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides. Réfléchis étape par étape.
#
# user: {0}

# %%
plot_precision(RUN_IDS[5], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[5], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[5], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[6]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides. Réfléchis étape par étape.
#
# user: {0}

# %%
plot_precision(RUN_IDS[6], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[6], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[6], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[7]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides. Réfléchis étape par étape.
#
# user: {0}

# %%
plot_precision(RUN_IDS[7], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[7], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[7], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[8]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides. Réfléchis étape par étape.
#
# user: {0}

# %%
plot_precision(RUN_IDS[8], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[8], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[8], save_folder="images/experience_2/metrics")

# %%
print_prompts(RUN_INFOS[9]["prompts"])
# Out:
# system: Ton rôle est d'attribuer un thème à une question posée par un député à l'Assemblée nationale française. La liste des thèmes est la suivante :
# - retraites
# - ministères et secrétariats d'état
# - handicapés
# - enseignement
# - politique extérieure
# - agriculture
# - logement
# - anciens combattants et victimes de guerre
# - énergie et carburants
# - impôts et taxes
# - sécurité sociale
# - justice
# - entreprises
# - outre-mer
# - déchets, pollution et nuisances
# - communes
# - commerce et artisanat
# - sports
# - consommation
# - famille
# - étrangers
# Le thème assigné doit être un des thèmes de la liste fournie. Seuls les thèmes de la liste précédente sont valides. Réfléchis étape par étape.
#
# user: {0}

# %%
plot_precision(RUN_IDS[9], save_folder="images/experience_2/metrics")
plot_recall(RUN_IDS[9], save_folder="images/experience_2/metrics")
plot_f1_score(RUN_IDS[9], save_folder="images/experience_2/metrics")

# %% [markdown]
# ## Comparing the strategies

# %%
plot_precision_heatmap(RUN_IDS)
plot_recall_heatmap(RUN_IDS)
plot_f1_score_heatmap(RUN_IDS)

# %% [markdown]
# ### Inter-coder agreement (Cohen’s Kappa / Krippendorff’s alpha)
#
# Here, we take at the **inter-coder agreement** between every runs. The first metrics we're looking for is the **Krippendorff's Alpha**, which measures the degree of agreement between different annotators beyond what would be expected by chance. In other words, it tells you how much the annotators agree with each other when categorizing or labeling items, considering the possibility of random agreement.
#
# Krippendorff’s Alpha ranges from -1 to 1:
#
# - **1** means perfect agreement: All annotators classified every item the same way.
#   - 0.81 - 1.00 : Almost perfect agreement;
#   - 0.61 - 0.80 : Substantial agreement;
#   - 0.41 - 0.60 : Moderate agreement;
#   - 0.21 - 0.40 : Fair agreement;
#   - 0.00 - 0.20 : Slight agreement.
# - **0** means no agreement beyond what would be expected by chance.
# - **Negative values** indicate that the agreement is worse than chance, meaning there is systematic disagreement among annotators.

# %%
print(f"Krippendorff's alpha : {compute_krippendorff_alpha(RUN_IDS):.2f}")
# Out:
# Krippendorff's alpha : 0.98

# %% [markdown]
# ## Confidence

# %%
plot_confidence_calibration_curve(RUN_IDS[0], ConfidenceType.Logprobs)
# Out:
# 100%|██████████| 1495/1495 [00:00<00:00, 44158.96it/s]

# %% [markdown]
# ## Statistical tests
