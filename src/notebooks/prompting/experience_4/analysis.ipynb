# %%
import os

os.sys.path.append(os.path.join(os.getcwd(), "../../.."))
from charts.cohen import plot_cohen_kappa
from models.LLMOutput import ConfidenceType
from utils.helpers import print_prompts
from metrics.run import gather_data_for_run_ids
from charts.calibration import plot_confidence_calibration_curve
from metrics.agreement.krippendorff import compute_krippendorff_alpha
from charts.performance import (
    plot_precision,
    plot_average_precision,
    plot_precision_heatmap,
    plot_recall,
    plot_average_recall,
    plot_recall_heatmap,
    plot_f1_score,
    plot_average_f1_score,
    plot_f1_score_heatmap,
    plot_support_counts,
)
from tables.performance import plot_precisions_table, plot_recalls_table, plot_fscores_table

# %% [markdown]
# # Analyzing results for experience #4

# %%
RUN_IDS = [
    "6709a6ad60a261cac7c00a28",
    "66fbcb96f2cbcffde184b529",
    "66fd09abf0f5bd541c250d80",
    "66fd0d8a7fb926541ed25695",
    "6709a6ca100fa082f3ccab78",
    "66fd14583ab53e2eefe440da",
    "66fd1af17b5f2e62b26d7363",
    "66fd23d36b539c98503a8ebd",
    "6709acf06e7d5ea42c208ac6",
    "66fed9fe72be35983ac45346",
    "6706c9f1553b1428d9d3c698",
    "6706d46903ed569f30198272",
    "6706dffdf297e93ecf8c66e1",
    "6709b776de3efa2502ae1a16",
    "6709be6ef73e515b9f8c0a80",
    "6709ccad394b0a246dfa05d6",
    "6709ba890a1c43e37e13367d",
    "6709e2163d7fd191961d61aa",
    "6709fbaea533458d3be2affc",
    "670a64eac399a40942c2bd71",
    "670a866a2e8b8a742455a112",
    "670a9875e984a991e7463816",
    "670aaafc34a1bef9fe29f848",
    "670b10905eab5a87890d6103",
]

SEPARATED_RUN_IDS = [
    # zero shot
    ["6709a6ad60a261cac7c00a28",
    "66fbcb96f2cbcffde184b529",
    "66fd09abf0f5bd541c250d80",
    "66fd0d8a7fb926541ed25695",
    # few shot 5
    "6709acf06e7d5ea42c208ac6",
    "66fed9fe72be35983ac45346",
    "6706c9f1553b1428d9d3c698",
    "6706d46903ed569f30198272",
    # few shot 5 cot
    "6709ba890a1c43e37e13367d",
    "6709e2163d7fd191961d61aa",
    "6709fbaea533458d3be2affc",
    "670a64eac399a40942c2bd71",],
    # zero shot proxy
    ["6709a6ca100fa082f3ccab78",
    "66fd14583ab53e2eefe440da",
    "66fd1af17b5f2e62b26d7363",
    "66fd23d36b539c98503a8ebd",
    # few shot 5 proxy
    "6706dffdf297e93ecf8c66e1",
    "6709b776de3efa2502ae1a16",
    "6709be6ef73e515b9f8c0a80",
    "6709ccad394b0a246dfa05d6",
    # few shot 5 cot proxy
    "670a866a2e8b8a742455a112",
    "670a9875e984a991e7463816",
    "670aaafc34a1bef9fe29f848",
    "670b10905eab5a87890d6103",],
]

# RUN_INFOS = gather_data_for_run_ids(RUN_IDS)

# %% [markdown]
# Each runs is based on the same batch of questions. Here is the themes distribution for the batch used in the experiment :

# %%
plot_support_counts(RUN_IDS, save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[0]["prompts"])

# %%
plot_precision(RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[0], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[1]["prompts"])

# %%
plot_precision(RUN_IDS[1], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[1], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[1], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[2]["prompts"])

# %%
plot_precision(RUN_IDS[2], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[2], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[2], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[3]["prompts"])

# %%
plot_precision(RUN_IDS[3], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[3], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[3], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[4]["prompts"])

# %%
plot_precision(RUN_IDS[4], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[4], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[4], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[5]["prompts"])

# %%
plot_precision(RUN_IDS[5], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[5], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[5], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[6]["prompts"])

# %%
plot_precision(RUN_IDS[6], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[6], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[6], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[7]["prompts"])

# %%
plot_precision(RUN_IDS[7], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[7], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[7], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[8]["prompts"])

# %%
plot_precision(RUN_IDS[8], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[8], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[8], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[9]["prompts"])

# %%
plot_precision(RUN_IDS[9], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[9], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[9], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[10]["prompts"])

# %%
plot_precision(RUN_IDS[10], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[10], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[10], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[11]["prompts"])

# %%
plot_precision(RUN_IDS[11], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[11], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[11], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[12]["prompts"])

# %%
plot_precision(RUN_IDS[12], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[12], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[12], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[13]["prompts"])

# %%
plot_precision(RUN_IDS[13], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[13], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[13], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[14]["prompts"])

# %%
plot_precision(RUN_IDS[14], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[14], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[14], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[15]["prompts"])

# %%
plot_precision(RUN_IDS[15], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[15], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[15], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[16]["prompts"])

# %%
plot_precision(RUN_IDS[16], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[16], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[16], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[17]["prompts"])

# %%
plot_precision(RUN_IDS[17], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[17], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[17], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[18]["prompts"])

# %%
plot_precision(RUN_IDS[18], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[18], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[18], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[19]["prompts"])

# %%
plot_precision(RUN_IDS[19], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[19], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[19], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[20]["prompts"])

# %%
plot_precision(RUN_IDS[20], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[20], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[20], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[21]["prompts"])

# %%
plot_precision(RUN_IDS[21], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[21], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[21], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[22]["prompts"])

# %%
plot_precision(RUN_IDS[22], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[22], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[22], save_folder="images/experience_4/metrics")

# %%
# print_prompts(RUN_INFOS[23]["prompts"])

# %%
plot_precision(RUN_IDS[23], save_folder="images/experience_4/metrics")
plot_recall(RUN_IDS[23], save_folder="images/experience_4/metrics")
plot_f1_score(RUN_IDS[23], save_folder="images/experience_4/metrics")

# %% [markdown]
# ## Comparing the strategies

# %% [markdown]
# ## Averages

# %%
plot_average_precision(RUN_IDS, save_folder="images/experience_4/metrics")
plot_average_recall(RUN_IDS, save_folder="images/experience_4/metrics")
plot_average_f1_score(RUN_IDS, save_folder="images/experience_4/metrics")

# %% [markdown]
# ## Heatmaps

# %%
plot_precision_heatmap(SEPARATED_RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_precision_heatmap(SEPARATED_RUN_IDS[1], save_folder="images/experience_4/metrics", title="Precision heatmap for each theme in specified runs (proxy)")
plot_recall_heatmap(SEPARATED_RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_recall_heatmap(SEPARATED_RUN_IDS[1], save_folder="images/experience_4/metrics", title="Recall heatmap for each theme in specified runs (proxy)")
plot_f1_score_heatmap(SEPARATED_RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_f1_score_heatmap(SEPARATED_RUN_IDS[1], save_folder="images/experience_4/metrics", title="F1 Score heatmap for each theme in specified runs (proxy)")

# %% [markdown]
# ## Tables

# %%
plot_precisions_table(SEPARATED_RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_precisions_table(SEPARATED_RUN_IDS[1], title="F1 score of different prompt settings per topic label (proxy)", save_folder="images/experience_4/metrics")
plot_recalls_table(SEPARATED_RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_recalls_table(SEPARATED_RUN_IDS[1], title="F1 score of different prompt settings per topic label (proxy)", save_folder="images/experience_4/metrics")
plot_fscores_table(SEPARATED_RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_fscores_table(SEPARATED_RUN_IDS[1], title="F1 score of different prompt settings per topic label (proxy)", save_folder="images/experience_4/metrics")

# %% [markdown]
# # Inter-coder agreement (Cohen’s Kappa / Krippendorff’s alpha)
#
# Here, we take at the **inter-coder agreement** between every runs. The first metrics we're looking for is the **Krippendorff's Alpha**, which measures the degree of agreement between different annotators beyond what would be expected by chance. In other words, it tells you how much the annotators agree with each other when categorizing or labeling items, considering the possibility of random agreement.
#
# Krippendorff’s Alpha ranges from -1 to 1:
#
# - **1** means perfect agreement: All annotators classified every item the same way.
#   - 0.81 - 1.00 : Almost perfect agreement;
#   - 0.61 - 0.80 : Substantial agreement;
#   - 0.41 - 0.60 : Moderate agreement;
#   - 0.21 - 0.40 : Fair agreement;
#   - 0.00 - 0.20 : Slight agreement.
# - **0** means no agreement beyond what would be expected by chance.
# - **Negative values** indicate that the agreement is worse than chance, meaning there is systematic disagreement among annotators.

# %%
print(f"Krippendorff's alpha : {compute_krippendorff_alpha(RUN_IDS):.2f}")

# %%
plot_cohen_kappa(SEPARATED_RUN_IDS[0], save_folder="images/experience_4/metrics")
plot_cohen_kappa(SEPARATED_RUN_IDS[1], save_folder="images/experience_4/metrics", alias="proxy")

# %% [markdown]
# ## Confidence

# %%
for RUN_ID in RUN_IDS:
    plot_confidence_calibration_curve(RUN_ID, ConfidenceType.Logprobs, save_folder="images/experience_4/metrics")

# %% [markdown]
# ## Statistical tests

# %%
# plot_stats(RUN_IDS)
